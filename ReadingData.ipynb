# %% [markdown]
# <a href="https://colab.research.google.com/github/MyDearGreatTeacher/AI4high/blob/master/ReadingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 使用pandas讀取資料

# %% [markdown]
# ## 使用pandas讀取遠方網站資料

# %%
import pandas as pd

train_url = "https://storage.googleapis.com/kaggle_datasets/House-Prices-Advanced-Regression-Techniques/train.csv"
test_url = "https://storage.googleapis.com/kaggle_datasets/House-Prices-Advanced-Regression-Techniques/test.csv"

labeled_df = pd.read_csv(train_url)
test_df = pd.read_csv(test_url)

# %%
print(labeled_df.shape)
print(test_df.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %%
labeled_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(labeled_df["LotArea"], labeled_df["SalePrice"])
plt.show()

# %%
import seaborn as sns

sns.stripplot(x="LotArea", y="SalePrice", data=labeled_df,
             jitter=True)
#plt.xlim(0, 250000)
plt.show()

# %% [markdown]
# ## 使用pandas讀取github網站CSV資料
#
# 讀取網站資料時特別注意要用raw資料的網址
#
# url = "https://raw.githubusercontent.com/MyDearGreatTeacher/AI4high/master/data/XXX.csv"

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/MyDearGreatTeacher/AI4high/master/data/stock_index_data.csv"


stockIndexDataDF = pd.read_csv(url)

stockIndexDataDF
# Out:
#   TradingDate   Nasdaq  S&P 500  Russell 2000
# 0  2014/01/30  4123.13  1794.19       1139.36
# 1  2014/01/31  4103.88  1782.59       1130.88
# 2  2014/02/03  3996.96  1741.89       1094.58
# 3  2014/02/04  4031.52  1755.20       1102.84
# 4  2014/02/05  4011.55  1751.64       1093.59
# 5  2014/02/06  4057.12  1773.43       1103.93

# %% [markdown]
# ## 使用pandas讀取github網站txt資料

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/MyDearGreatTeacher/AI4high/master/data/fb_post_dates_chapter%208.txt"

fbdata_df=pd.read_csv(url, sep='|', parse_dates=[0], header=None,names=['Date','Time'])
fbdata_df.head()
# Out:
#         Date         Time
# 0 2014-09-30   2:43am EDT
# 1 2014-09-30   2:22am EDT
# 2 2014-09-30   2:06am EDT
# 3 2014-09-30   1:07am EDT
# 4 2014-09-28   9:16pm EDT

# %% [markdown]
# ## 使用pandas讀取google colab資料

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cce96167-4c18-45d2-b42b-73fd2f9718ae" name="files[]" multiple disabled />
#      <output id="result-cce96167-4c18-45d2-b42b-73fd2f9718ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stock_index_data.csv to stock_index_data.csv

# %%
# !ls
# Out:
# sample_data  stock_index_data.csv

# %%
stockIndexDataDF=pd.read_csv('./stock_index_data.csv')
stockIndexDataDF
# Out:
#   TradingDate   Nasdaq  S&P 500  Russell 2000
# 0  2014/01/30  4123.13  1794.19       1139.36
# 1  2014/01/31  4103.88  1782.59       1130.88
# 2  2014/02/03  3996.96  1741.89       1094.58
# 3  2014/02/04  4031.52  1755.20       1102.84
# 4  2014/02/05  4011.55  1751.64       1093.59
# 5  2014/02/06  4057.12  1773.43       1103.93

# %% [markdown]
# # 使用pandas讀取google drive資料
#
# 待完成

# %% [markdown]
# # 用 Python 抓取 Ubike 開放資料
#
#
# https://jerrynest.io/python-get-ubike-opendata/
#
#
# https://colab.research.google.com/drive/1jQprW8RIsA_SEFpBm6POF8DgZ1XZ9YH6#scrollTo=A8qmjnFmGyNv

# %% [markdown]
# ### Ubike 資料說明
#
# 每筆資料有以下 14 個欄位，其中有部分是不會變動的資料，如 sno、sna、sarea 等等，待會放資料庫時會獨立出來放
#
# sno：站點代號
#
#  sna：場站名稱(中文)
#
#  tot：場站總停車格
#
#  sbi：場站目前車輛數量
#
#  sarea：場站區域(中文)
#
#  mday：資料更新時間
#
#  lat：緯度
#
#  lng：經度
#
#  ar：地(中文)
#
#  sareaen：場站區域(英文)
#
#  snaen：場站名稱(英文)
#
#  aren：地址(英文)
#
#  bemp：空位數量
#
#  act：全站禁用狀態

# %%
import requests
import json

url = "http://data.taipei/youbike"
data = requests.get(url).json()

print(data)

for key, value in data["retVal"].items():
  sno = value["sno"]
  sna = value["sna"]
  print("NO.", sno, sna)
# Out:
# {'retCode': 1, 'retVal': {'0001': {'sno': '0001', 'sna': '捷運市政府站(3號出口)', 'tot': '180', 'sbi': '139', 'sarea': '信義區', 'mday': '20190421010417', 'lat': '25.0408578889', 'lng': '121.567904444', 'ar': '忠孝東路/松仁路(東南側)', 'sareaen': 'Xinyi Dist.', 'snaen': 'MRT Taipei City Hall Stataion(Exit 3)-2', 'aren': 'The S.W. side of Road Zhongxiao East Road & Road Chung Yan.', 'bemp': '40', 'act': '1'}, '0002': {'sno': '0002', 'sna': '捷運國父紀念館站(2號出口)', 'tot': '48', 'sbi': '18', 'sarea': '大安區', 'mday': '20190421010419', 'lat': '25.041254', 'lng': '121.55742', 'ar': '忠孝東路四段/光復南路口(西南側)', 'sareaen': 'Daan Dist.', 'snaen': 'MRT S.Y.S Memorial Hall Stataion(Exit 2.)', 'aren': 'Sec,4. Zhongxiao E.Rd/GuangFu S. Rd', 'bemp': '28', 'act': '1'}, '0003': {'sno': '0003', 'sna': '台北市政府', 'tot': '40', 'sbi': '25', 'sarea': '信義區', 'mday': '20190421010427', 'lat': '25.0377972222', 'lng': '121.565169444', 'ar': '台北市政府東門(松智路) (鄰近信義商圈/台北探索館)', 'sareaen': 'Xinyi Dist.', 'snaen': 'Taipei City Hall', 'aren': 'Taipei City Go
# ...
